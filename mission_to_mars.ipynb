# %%
# Dependencies
import pandas as pd
from bs4 import BeautifulSoup as bs
from webdriver_manager.chrome import ChromeDriverManager
from splinter import Browser

# %% [markdown]
# # NASA Mars News

# %%
# Setup splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [C:\Users\bfo2f\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache

# %%
# URL of page to be scraped
url = 'https://redplanetscience.com/'

browser.visit(url)

html = browser.html
soup = bs(html, 'html.parser')

# %%
# Retrieve the parent divs for all articles
results = soup.find_all('div', class_='list_text')[0]

news_title = results.find('div', class_='content_title').text

news_p = results.find('div', class_='article_teaser_body').text

print('-----------------')
print(news_title)
print(news_p)
# Out:
# -----------------
# NASA's Push to Save the Mars InSight Lander's Heat Probe
# The scoop on the end of the spacecraft's robotic arm will be used to 'pin' the mole against the wall of its hole.

# %% [markdown]
# # JPL Mars Space Images - Featured Image

# %%
# Setup splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

url = 'https://spaceimages-mars.com/'

browser.visit(url)

browser.links.find_by_partial_text('FULL IMAGE').click()

# why do I have to do this again?
html = browser.html
soup = bs(html, 'html.parser')


fancy_image = soup.find('img', class_='fancybox-image')['src']
fancy_image = url + fancy_image
print(fancy_image)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [C:\Users\bfo2f\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# https://spaceimages-mars.com/image/featured/mars2.jpg

# %% [markdown]
# # Mars Facts

# %%
# URL of page to be scraped
url = 'https://galaxyfacts-mars.com/'


mfv = pd.read_html(url)[0]
print(mfv)
# Out:
#                          0                1                2
# 0  Mars - Earth Comparison             Mars            Earth
# 1                Diameter:         6,779 km        12,742 km
# 2                    Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
# 3                   Moons:                2                1
# 4       Distance from Sun:   227,943,824 km   149,598,262 km
# 5          Length of Year:   687 Earth days      365.24 days
# 6             Temperature:     -87 to -5 °C      -88 to 58°C

# %% [markdown]
# # Mars Hemispheres

# %%
# URL of page to be scraped
url = 'https://marshemispheres.com/'

# Store images into a list
hemisphere_image_urls = [
    {"title": "Valles Marineris Hemisphere", "img_url": "https://marshemispheres.com/images/valles_marineris_enhanced-full.jpg"},
    {"title": "Cerberus Hemisphere", "img_url": "https://marshemispheres.com/images/full.jpg"},
    {"title": "Schiaparelli Hemisphere", "img_url": "https://marshemispheres.com/images/schiaparelli_enhanced-full.jpg"},
    {"title": "Syrtis Major Hemisphere", "img_url": "https://marshemispheres.com/images/syrtis_major_enhanced-full.jpg"},
]

# Visit website for images
browser.visit(url)

browser.links.find_by_partial_text('Hemipshere Enhanced')[0].click()

# # maybe make and append list like above before going for next one
# html = browser.html
# soup = bs(html, 'html.parser')
# hemi1 = soup.find('img', class_='wide-image')['src']
# hemi1 = url + hemi1
H
# print(hemi1)

browser.back()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\splinter\element_list.py in __getitem__(self, index)
#      38         try:
# ---> 39             return self._container[index]
#      40         except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# ElementDoesNotExist                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17324/2213293072.py in <module>
#      13 browser.visit(url)
#      14
# ---> 15 browser.links.find_by_partial_text('Hemipshere Enhanced')[0].click()
#      16
#      17 # # maybe make and append list like above before going for next one
#
# ~\AppData\Roaming\Python\Python39\site-packages\splinter\element_list.py in __getitem__(self, index)
#      39             return self._container[index]
#      40         except IndexError:
# ---> 41             raise ElementDoesNotExist(
#      42                 u'no elements could be found with {0} "{1}"'.format(
#      43                     self.find_by, self.query
#
# ElementDoesNotExist: no elements could be found with link by partial text "Hemipshere Enhanced"
